# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {"a" : [4, 5, 6, 7],     # 열 이름을 지정해 주고 시리즈 형태로 데이터를 저장합니다.
     "b" : [8, 9, 10, 11],
     "c" : [12, 13, 14, 15]},
    index=[1, 2, 3, 4])       # 인덱스는 1, 2, 3, 4로 정해 줍니다.

# %%
df
# Out:
#    a   b   c
# 1  4   8  12
# 2  5   9  13
# 3  6  10  14
# 4  7  11  15

# %%
df = pd.DataFrame(
    [[4,8,12],
     [5,9,13],
     [6,10,14],
     [7,11,15]],
    index=[1,2,3,4],
    columns=['a','b','d'])

# %%
df
# Out:
#    a   b   d
# 1  4   8  12
# 2  5   9  13
# 3  6  10  14
# 4  7  11  15

# %%
df = pd.DataFrame(
    {'a':[4,5,6,7],
     'b':[8,9,10,11],
     'c':[12,13,14,15]},
    index=pd.MultiIndex.from_tuples(
        [('d',1),('d',2),('e',1),('e',2)],
        names=['n','v']))

# %%
df
# Out:
#      a   b   c
# n v
# d 1  4   8  12
#   2  5   9  13
# e 1  6  10  14
#   2  7  11  15

# %%
df.sort_values('a',ascending=False)
# Out:
#      a   b   c
# n v
# e 2  7  11  15
#   1  6  10  14
# d 2  5   9  13
#   1  4   8  12

# %%
df.rename(columns={'c':'d'})
# Out:
#      a   b   d
# n v
# d 1  4   8  12
#   2  5   9  13
# e 1  6  10  14
#   2  7  11  15

# %%
df.reset_index()
# Out:
#    n  v  a   b   c
# 0  d  1  4   8  12
# 1  d  2  5   9  13
# 2  e  1  6  10  14
# 3  e  2  7  11  15

# %%
df.sort_index()
# Out:
#      a   b   c
# n v
# d 1  4   8  12
#   2  5   9  13
# e 1  6  10  14
#   2  7  11  15

# %%
df.drop(columns=['a','b'])
# Out:
#       c
# n v
# d 1  12
#   2  13
# e 1  14
#   2  15

# %%
df.head(2)
# Out:
#      a  b   c
# n v
# d 1  4  8  12
#   2  5  9  13

# %%
df.tail(2)
# Out:
#      a   b   c
# n v
# e 1  6  10  14
#   2  7  11  15

# %%
df[df['a']>4]
# Out:
#      a   b   c
# n v
# d 2  5   9  13
# e 1  6  10  14
#   2  7  11  15

# %%
df[df['a'] == 6]
# Out:
#      a   b   c
# n v
# e 1  6  10  14

# %%
df[df['a'] != 5]
# Out:
#      a   b   c
# n v
# d 1  4   8  12
# e 1  6  10  14
#   2  7  11  15

# %%
df[df['a'].isin([4])]
# Out:
#      a  b   c
# n v
# d 1  4  8  12

# %%
df.sample(frac=0.75)
# Out:
#      a   b   c
# n v
# e 2  7  11  15
#   1  6  10  14
# d 1  4   8  12

# %%
df.sample(n=3)
# Out:
#      a   b   c
# n v
# e 2  7  11  15
# d 1  4   8  12
#   2  5   9  13

# %%
df.nlargest(3, 'a')
# Out:
#      a   b   c
# n v
# e 2  7  11  15
#   1  6  10  14
# d 2  5   9  13

# %%
df.nsmallest(3, 'a')
# Out:
#      a   b   c
# n v
# d 1  4   8  12
#   2  5   9  13
# e 1  6  10  14

# %%
df.iloc[1:4]  # 1번 2번 3번에 해당하는 행을 불러와라(2번째, 3번째, 4번째 행)
# Out:
#      a   b   c
# n v
# d 2  5   9  13
# e 1  6  10  14
#   2  7  11  15

# %%
df.iloc[0, 1]
# Out:
# 8

# %%
df.iloc[:,:]
# Out:
#      a   b   c
# n v
# d 1  4   8  12
#   2  5   9  13
# e 1  6  10  14
#   2  7  11  15

# %%
df.iloc[0:1,3:4]
# Out:
# Empty DataFrame
# Columns: []
# Index: [(d, 1)]

# %%
df.loc[:,'b']
# Out:
# n  v
# d  1     8
#    2     9
# e  1    10
#    2    11
# Name: b, dtype: int64

# %%
df.index.names        # ['n', 'v']를 보여줌
# Out:
# FrozenList(['n', 'v'])

# %%
df.index.get_level_values('n')  # 인덱스의 'n' 레벨 값들만 가져옴
# Out:
# Index(['d', 'd', 'e', 'e'], dtype='object', name='n')

# %%
df.xs('d', level='n')           # 'n' 레벨에서 'd'만 추출
# Out:
#    a  b   c
# v
# 1  4  8  12
# 2  5  9  13

# %%
df.iloc[:]
# Out:
#      a   b   c
# n v
# d 1  4   8  12
#   2  5   9  13
# e 1  6  10  14
#   2  7  11  15

# %%
df[['a','b']]
# Out:
#      a   b
# n v
# d 1  4   8
#   2  5   9
# e 1  6  10
#   2  7  11

# %%
df.xs('d', level='n')    # d인 모든 행 가져오기!
# Out:
#    a  b   c
# v
# 1  4  8  12
# 2  5  9  13

# %%
df.filter(regex='c')
# Out:
#       c
# n v
# d 1  12
#   2  13
# e 1  14
#   2  15

# %%
df.filter(regex='^(?!c$).*')
# Out:
#      a   b
# n v
# d 1  4   8
#   2  5   9
# e 1  6  10
#   2  7  11

# %%
df.iloc[0:3, 0:2]
# Out:
#      a   b
# n v
# d 1  4   8
#   2  5   9
# e 1  6  10

# %%
df.max()
# Out:
# a     7
# b    11
# c    15
# dtype: int64
